# %%
# %pip install pandas
# %pip install lightgbm
# %pip install scikit-learn
# %pip install optuna
import glob
import pandas as pd
import numpy as np
# import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae
import optuna.integration.lightgbm as lgb_tune
import optuna.integration.lightgbm as lgb
# Out:
# Requirement already satisfied: pandas in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: six>=1.5 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lightgbm in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (4.1.0)
# Requirement already satisfied: scipy in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from lightgbm) (1.11.3)
# Requirement already satisfied: numpy in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from lightgbm) (1.26.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from scikit-learn) (1.11.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: optuna in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (3.4.0)
# Requirement already satisfied: tqdm in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from optuna) (2.0.22)
# Requirement already satisfied: alembic>=1.5.0 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from optuna) (1.12.0)
# Requirement already satisfied: colorlog in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from optuna) (23.2)
# Requirement already satisfied: numpy in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from optuna) (1.26.0)
# Requirement already satisfied: typing-extensions>=4 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.8.0)
# Requirement already satisfied: Mako in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/iori/workspace/Nishika/myenv/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
excel=pd.ExcelFile('data_explanation.xlsx')
sheets=excel.sheet_names
num_sheets=len(sheets)
print(sheets)
print(num_sheets)
# Out:
# ['データ説明', '\u3000カラム説明']
# 2

# %%
data_explanation=excel.parse(sheets[0])
data_explanation
# Out:
#                    ファイル名           内容
# 0              train.csv       訓練用データ
# 1               test.csv       評価用データ
# 2            weather.csv        天候データ
# 3  sample_submission.csv  投稿データフォーマット

# %%
col_explanation=excel.parse(sheets[1])
col_explanation
# Out:
#           ファイル名           カラム名                                          内容
# 0     train.csv           kind                                       野菜の種類
# 1           NaN           date                                          日付
# 2           NaN         amount     卸売数量合計（合計の意味は、複数産地のものがあればその合計をとっているの意味）
# 3           NaN     mode_price  卸売価格中央値（中央値の意味は、複数産地のものがあればその中央値をとっているの意味）
# 4           NaN           area                  産地。複数産地のものが売られていた場合は"_"で結合
# 5           NaN           year                                           年
# 6           NaN         weekno                                         週番号
# 7      test.csv           kind                                       野菜の種類
# 8           NaN           date                                          日付
# 9           NaN           area                  産地。複数産地のものが売られていた場合は"_"で結合
# 10          NaN           year                                           年
# 11          NaN         weekno                                         週番号
# 12  weather.csv           date                                          日付
# 13          NaN      mean_temp                                     平均気温（℃）
# 14          NaN       max_temp                                     最高気温（℃）
# 15          NaN  max_temp_time                                 最高気温（℃）（時分）
# 16          NaN       min_temp                                     最低気温（℃）
# 17          NaN  min_temp_time                                 最低気温（℃）（時分）
# 18          NaN       sum_rain                                   降水量合計（mm）
# 19          NaN       sun_time                                    日照時間（時間）
# 20          NaN     mean_humid                                     平均湿度（%）
# 21          NaN           area                                         エリア
